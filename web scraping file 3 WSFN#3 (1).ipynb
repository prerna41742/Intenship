# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of Amazon.in
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# <ipython-input-4-91be80dd5bfb>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
# Enter the product you want to search : guitar

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    
search_bar.clear()                                               
search_bar.send_keys(user_inp)                                   
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       
search_button.click()
# Out:
# <ipython-input-5-b7e4c84a6325>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("twotabsearchtextbox")
# <ipython-input-5-b7e4c84a6325>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')

# %% [markdown]
# Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# <ipython-input-7-31aba433719e>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url='https://images.google.com/'
urls = []    # empty list for image urls to download
data = []    # empty list for storing data
search_item = ["Fruits", "Cars", "Machine Learning"]
for item in search_item:
    driver.get(url)  # performing a Google search for our selected items
    time.sleep(3)
    search_bar = driver.find_element_by_tag_name("input")     # finding search bar on Google page   
    search_bar.send_keys(str(item))      # send search item list    
    search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click() # now we will click on search button
    
    # scroll the page in order to generate more images on the website
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,100)")        
        imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:100]:      # getting only 100 images each
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 300:
        break
    print("Obtaining {0} of {1} images".format(i, 300))
    response=requests.get(urls[i])
    file = open(r"D:\Fliprobo projects\Google Images\images"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-8-3d7a21af31b5>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_tag_name("input")     # finding search bar on Google page
# <ipython-input-8-3d7a21af31b5>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click() # now we will click on search button
# <ipython-input-8-3d7a21af31b5>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")

# %% [markdown]
# Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# opning flipkart.com
driver.get('https://www.flipkart.com/')
time.sleep(3)
try:
    login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
    login_X_button.click()
except NoSuchElementException : 
    print("No Login page")
    
search_bar = driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    # Finding the search bar using it's xpath
search_bar.clear()               # Clearing the search bar
search_bar.send_keys("pixel")       # Inputing keyword to search
search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')    # Finding the xpath of search button
search_button.click()        # Clicking the search button
# Out:
# <ipython-input-26-63187c77fd99>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
# <ipython-input-26-63187c77fd99>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
# <ipython-input-26-63187c77fd99>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    # Finding the search bar using it's xpath
# <ipython-input-26-63187c77fd99>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')    # Finding the xpath of search button

# %%
# Fetching urls of phones coming on 1st page
flip_urls = []
urls = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for url in urls:
    flip_urls.append(url.get_attribute("href"))
    
    
    
#Make empty lists   
flip_dict = {}
flip_dict["Brand"] = []
flip_dict["Smartphone"] = []
flip_dict["Colour"] = []
flip_dict["RAM"] = []
flip_dict["Storage(ROM)"] = []
flip_dict["Primary Camera"] = []
flip_dict["Secondary Camera"] = []
flip_dict["Display Size"] = []
flip_dict["Battery Capacity"] = []
flip_dict["Battery Type"] = []
flip_dict["Price"] = []
flip_dict["URL"] = []
# Out:
# <ipython-input-27-634d350834cf>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls = driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')

# %%
# Scraping data from each url
for url in flip_urls:
    driver.get(url)    # Saving url                                                     
    print("Scraping URL = ", url)
    flip_dict['URL'].append(url)                                                          # Loading the webpage by url
    time.sleep(2)
    
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     # Button for expanding the specs
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")
    
    try:
        brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      # Extracting Brand from xpath
        flip_dict["Brand"].append(brand.text.split()[0])
    except NoSuchElementException:
        flip_dict['Brand'].append('-')
        
    try:
        price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      # Extracting Price from xpath
        flip_dict['Price'].append(price.text)
    except NoSuchElementException:
        flip_dict['Price'].append('-')
        
    try:
        name = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')      # Extracting Name from xpath
        flip_dict['Smartphone'].append(name.text)
    except NoSuchElementException:
        flip_dict['Smartphone'].append('-')
    
    try:
        color = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      # Extracting colour from xpath
        flip_dict['Colour'].append(color.text)
    except NoSuchElementException:
        flip_dict['Colour'].append('-')
    
    try:
        disp_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
        if disp_chk.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  # Extracting Display Size from xpath
        flip_dict['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        flip_dict['Display Size'].append('-')
        
    try:
        rom = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')         # Extracting Storage(ROM) from xpath
        flip_dict['Storage(ROM)'].append(rom.text)
    except NoSuchElementException:
        flip_dict['Storage(ROM)'].append('-')
    
    try:
        ram = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                # Extracting RAM from xpath
        flip_dict['RAM'].append(ram.text)
    except NoSuchElementException:
        flip_dict['RAM'].append('-')
    
    try:                                                                                  
        pri_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')     # Extracting Camera from xpath
        flip_dict['Primary Camera'].append(pri_cam.text)
    except NoSuchElementException:
        flip_dict['Primary Camera'].append('-')
    
    try:                                                                                    # Extracting Secondary Camera from xpath
        cam_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if cam_chk != "Secondary Camera" : 
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        flip_dict['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        flip_dict['Secondary Camera'].append('-')
        
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :   # Extracting Battery Capacity from xpath
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :     
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
                bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_chk.text != "Battery Capacity" : raise NoSuchElementException
            bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')                # Extracting Availability from xpath
        flip_dict['Battery Capacity'].append(bat_cap.text)
    except NoSuchElementException:
        flip_dict['Battery Capacity'].append('-')
    
    try:
        if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[2]/ul/li')
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[1]')
                if bat_chk.text != "Battery Type" : raise NoSuchElementException
                bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[1]')
            if bat_chk.text != "Battery Type" : raise NoSuchElementException
            bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[2]/ul/li')             # Extracting Battery Type from xpath
        flip_dict['Battery Type'].append(bat_typ.text)
    except NoSuchElementException:
        flip_dict['Battery Type'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# <ipython-input-28-b5e902cf7f5c>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     # Button for expanding the specs
# <ipython-input-28-b5e902cf7f5c>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      # Extracting Brand from xpath
# <ipython-input-28-b5e902cf7f5c>:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')      # Extracting Price from xpath
# <ipython-input-28-b5e902cf7f5c>:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')      # Extracting Name from xpath
# <ipython-input-28-b5e902cf7f5c>:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   color = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      # Extracting colour from xpath
# <ipython-input-28-b5e902cf7f5c>:39: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/div')
# <ipython-input-28-b5e902cf7f5c>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_size = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  # Extracting Display Size from xpath
# <ipython-input-28-b5e902cf7f5c>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rom = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')         # Extracting Storage(ROM) from xpath
# <ipython-input-28-b5e902cf7f5c>:53: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ram = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                # Extracting RAM from xpath
# <ipython-input-28-b5e902cf7f5c>:59: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pri_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')     # Extracting Camera from xpath
# <ipython-input-28-b5e902cf7f5c>:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   cam_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
# <ipython-input-28-b5e902cf7f5c>:67: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
# <ipython-input-28-b5e902cf7f5c>:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sec_cam = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
# <ipython-input-28-b5e902cf7f5c>:78: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :   # Extracting Battery Capacity from xpath
# <ipython-input-28-b5e902cf7f5c>:79: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
# <ipython-input-28-b5e902cf7f5c>:80: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
# <ipython-input-28-b5e902cf7f5c>:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')
# <ipython-input-28-b5e902cf7f5c>:98: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
# <ipython-input-28-b5e902cf7f5c>:99: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
# <ipython-input-28-b5e902cf7f5c>:100: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[1]')
# Scraping URL =  https://www.flipkart.com/google-pixel-3a-clearly-white-64-gb/p/itmfgk4jfgstaack?pid=MOBFFGFPJSCEXMSG&lid=LSTMOBFFGFPJSCEXMSGODGRZE&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFFGFPJSCEXMSG.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# <ipython-input-28-b5e902cf7f5c>:83: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
# <ipython-input-28-b5e902cf7f5c>:84: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
# <ipython-input-28-b5e902cf7f5c>:86: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
# <ipython-input-28-b5e902cf7f5c>:103: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
# <ipython-input-28-b5e902cf7f5c>:104: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/table/tbody/tr[2]/td[1]')
# Scraping URL =  https://www.flipkart.com/redmi-9-power-electric-green-64-gb/p/itmca7d78e222ed7?pid=MOBFYZ7AVAXXB2TH&lid=LSTMOBFYZ7AVAXXB2THVSAZKU&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFYZ7AVAXXB2TH.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# <ipython-input-28-b5e902cf7f5c>:90: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
# <ipython-input-28-b5e902cf7f5c>:92: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_cap = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')                # Extracting Availability from xpath
# <ipython-input-28-b5e902cf7f5c>:110: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_chk = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[1]')
# <ipython-input-28-b5e902cf7f5c>:112: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][10]/table/tbody/tr[2]/td[2]/ul/li')             # Extracting Battery Type from xpath
# Scraping URL =  https://www.flipkart.com/redmi-9-power-mighty-black-64-gb/p/itm481ab234a6553?pid=MOBFYZ94UWPWQRNF&lid=LSTMOBFYZ94UWPWQRNFKVNNCX&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFYZ94UWPWQRNF.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9-power-fiery-red-64-gb/p/itmcd78b9bc04aa9?pid=MOBFYZF8XVSHPK5M&lid=LSTMOBFYZF8XVSHPK5M6AFH5O&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFYZF8XVSHPK5M.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-m31-space-black-128-gb/p/itmed6043337ac0e?pid=MOBFUYQTCWZVMGEK&lid=LSTMOBFUYQTCWZVMGEKQRCZFI&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFUYQTCWZVMGEK.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# <ipython-input-28-b5e902cf7f5c>:102: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_typ = driver.find_element_by_xpath('//div[@class="_3k-BhJ"][9]/table/tbody/tr[2]/td[2]/ul/li')
# Scraping URL =  https://www.flipkart.com/itel-it2171/p/itmffygvnzbzeu6b?pid=MOBFPBQBH6HWXBPF&lid=LSTMOBFPBQBH6HWXBPF6TNO2O&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFPBQBH6HWXBPF.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/karbonn-kx3/p/itm60cf67471b066?pid=MOBFKVM39K9MDYFV&lid=LSTMOBFKVM39K9MDYFVYMNANT&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFKVM39K9MDYFV.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/karbonn-kx3/p/itmadce6075acf6c?pid=MOBFTEF84JRUPJGZ&lid=LSTMOBFTEF84JRUPJGZLBDSCV&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFTEF84JRUPJGZ.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/lava-gem/p/itm77ce2feac253b?pid=MOBFMR92XWMXWMKE&lid=LSTMOBFMR92XWMXWMKEX8E5VN&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFMR92XWMXWMKE.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/i-kall-k3310/p/itmevt8krrtzu2yx?pid=MOBG5UFBPHZPA38G&lid=LSTMOBG5UFBPHZPA38GPVFXFN&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG5UFBPHZPA38G.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Exception Occured. Moving to next page
# Scraping URL =  https://www.flipkart.com/i-kall-k3310/p/itmevt8krrtzu2yx?pid=MOBG5UFKC3WHGVHG&lid=LSTMOBG5UFKC3WHGVHGVM6WBM&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG5UFKC3WHGVHG.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/gfive-u707/p/itmfy49yredg3mtc?pid=MOBG6M4QDKVAGNU3&lid=LSTMOBG6M4QDKVAGNU3WNSX2L&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG6M4QDKVAGNU3.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-note-11t-5g-aquamarine-blue-128-gb/p/itm0dd08e65983e7?pid=MOBG9G5HY4X7WVFY&lid=LSTMOBG9G5HY4X7WVFYGXDDN5&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG9G5HY4X7WVFY.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-midnight-black-32-gb/p/itmeabd39a0cd669?pid=MOBFVDA2RWTCFBHZ&lid=LSTMOBFVDA2RWTCFBHZC9GCG4&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFVDA2RWTCFBHZ.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9a-nature-green-32-gb/p/itmeabd39a0cd669?pid=MOBFVDA5QCGNZKH9&lid=LSTMOBFVDA5QCGNZKH9LPVRPQ&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFVDA5QCGNZKH9.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-9-sky-blue-64-gb/p/itm4fb151383983b?pid=MOBFV5FPUS8UHG9H&lid=LSTMOBFV5FPUS8UHG9H5C92MI&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFV5FPUS8UHG9H.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/tecno-spark-7-magnet-black-32-gb/p/itmb5ba6405b2fec?pid=MOBG6FN2JPZXMAYU&lid=LSTMOBG6FN2JPZXMAYUYBX7Y5&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG6FN2JPZXMAYU.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/tecno-spark-7-spruce-green-32-gb/p/itmb5ba6405b2fec?pid=MOBG4KA4TZEJJJPS&lid=LSTMOBG4KA4TZEJJJPSBBHMUZ&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG4KA4TZEJJJPS.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/uismart-ui-06/p/itm04ebdbb597d46?pid=MOBFY2YJZPWSYMVJ&lid=LSTMOBFY2YJZPWSYMVJW4OR6N&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBFY2YJZPWSYMVJ.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/tecno-camon-17-frost-silver-128-gb/p/itm60b07aa2c3b00?pid=MOBG6ASFPK8XMVDW&lid=LSTMOBG6ASFPK8XMVDWY23XQA&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG6ASFPK8XMVDW.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/mtr-s600/p/itmfca730d72e443?pid=MOBG9BKKYUGSRJXP&lid=LSTMOBG9BKKYUGSRJXPYZPO9U&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG9BKKYUGSRJXP.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/mtr-s600/p/itmfca730d72e443?pid=MOBG9BKAXEQGYQRP&lid=LSTMOBG9BKAXEQGYQRP0HZAEU&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG9BKAXEQGYQRP.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d
# Scraping URL =  https://www.flipkart.com/redmi-note-10-lite-glacier-white-128-gb/p/itmde31f59064927?pid=MOBG7PRH8KHAHZNH&lid=LSTMOBG7PRH8KHAHZNHJFUT9F&marketplace=FLIPKART&q=pixel&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=SEARCH&iid=de61fc6c-df71-4a1c-85ee-ce6ba5e659d5.MOBG7PRH8KHAHZNH.SEARCH&ppt=hp&ppn=homepage&ssid=bnefrb8gog0000001640702124627&qH=ab4086ecd47c568d

# %%
print(len(flip_dict["Brand"]), len(flip_dict["Smartphone"]), len(flip_dict["Colour"]), len(flip_dict["Price"]), len(flip_dict['URL']))
# Out:
# 24 24 24 24 24

# %%
flip_df = pd.DataFrame.from_dict(flip_dict)
flip_df
# Out:
#       Brand          Smartphone           Colour     RAM Storage(ROM)  \
# 0    Google            Pixel 4a       Just Black    6 GB       128 GB
# 1    Google            Pixel 3a    Clearly White    4 GB        64 GB
# 2     REDMI             9 Power   Electric Green    4 GB        64 GB
# 3     REDMI             9 Power     Mighty Black    4 GB        64 GB
# 4     REDMI             9 Power        Fiery Red    4 GB        64 GB
# 5   SAMSUNG          Galaxy M31      Space Black    8 GB       128 GB
# 6      Itel              It2171        DEEP BLUE   32 MB        32 MB
# 7   KARBONN                 KX3        Black,Red   32 MB        32 MB
# 8   KARBONN                 KX3     White & Grey   31 MB        32 MB
# 9      LAVA                 Gem      Blue Gold S   32 MB        32 MB
# 10        -                   -                -       -            -
# 11        I               K3310         Sky Blue   32 MB        32 MB
# 12    GFive                U707        Black Red   32 MB        32 MB
# 13    REDMI   REDMI Note 11T 5G  Aquamarine Blue    8 GB       128 GB
# 14    Redmi            Redmi 9A   Midnight Black    2 GB        32 GB
# 15    Redmi            Redmi 9A     Nature Green    2 GB        32 GB
# 16    Redmi             Redmi 9         Sky Blue    4 GB        64 GB
# 17    Tecno             Spark 7     Magnet Black    2 GB        32 GB
# 18    Tecno             Spark 7     Spruce Green    2 GB        32 GB
# 19  UiSmart               Ui-06            Black  512 MB       256 MB
# 20    Tecno            Camon 17     Frost Silver    6 GB       128 GB
# 21      MTR                S600       Red, Black   32 MB        32 MB
# 22      MTR                S600      Gold, Black   32 MB        32 MB
# 23    REDMI  REDMI NOTE 10 LITE    Glacier White    4 GB       128 GB
#
#             Primary Camera   Secondary Camera          Display Size  \
# 0       12.2MP Rear Camera   8MP Front Camera  14.76 cm (5.81 inch)
# 1       12.2MP Rear Camera   8MP Front Camera   14.22 cm (5.6 inch)
# 2   48MP + 8MP + 2MP + 2MP   8MP Front Camera  16.59 cm (6.53 inch)
# 3   48MP + 8MP + 2MP + 2MP   8MP Front Camera  16.59 cm (6.53 inch)
# 4   48MP + 8MP + 2MP + 2MP   8MP Front Camera  16.59 cm (6.53 inch)
# 5   64MP + 8MP + 5MP + 5MP  32MP Front Camera   16.26 cm (6.4 inch)
# 6                        -                  -    4.57 cm (1.8 inch)
# 7        0.3MP Rear Camera                  -    4.57 cm (1.8 inch)
# 8                        -                  -    4.57 cm (1.8 inch)
# 9        1.3MP Rear Camera                  -    7.11 cm (2.8 inch)
# 10                       -                  -                     -
# 11                       -                  -    4.5 cm (1.77 inch)
# 12       0.3MP Rear Camera                  -    4.57 cm (1.8 inch)
# 13          Primary Camera                  -   16.76 cm (6.6 inch)
# 14        13MP Rear Camera                  -  16.59 cm (6.53 inch)
# 15        13MP Rear Camera                  -  16.59 cm (6.53 inch)
# 16              13MP + 2MP   5MP Front Camera  16.59 cm (6.53 inch)
# 17        16MP Rear Camera   8MP Front Camera  16.56 cm (6.52 inch)
# 18        16MP Rear Camera   8MP Front Camera  16.56 cm (6.52 inch)
# 19                       -                  -    4.5 cm (1.77 inch)
# 20        64MP + 2MP + 2MP  16MP Front Camera   17.27 cm (6.8 inch)
# 21                       -                  -     6.1 cm (2.4 inch)
# 22                       -                  -     6.1 cm (2.4 inch)
# 23          Primary Camera                  -  16.94 cm (6.67 inch)
#
#    Battery Capacity     Battery Type    Price  \
# 0          3140 mAh                -  ₹28,999
# 1          3000 mAh                -  ₹39,999
# 2          6000 mAh  Lithium-polymer  ₹13,899
# 3          6000 mAh  Lithium-polymer  ₹13,490
# 4          6000 mAh  Lithium-polymer  ₹13,295
# 5          6000 mAh      lithium-ion  ₹20,500
# 6                 -                -     ₹969
# 7           800 mAh           Li-ion     ₹911
# 8                 -                -     ₹924
# 9          1750 mAh           Li-Ion   ₹1,599
# 10                -                -        -
# 11         1000 mAh                -     ₹729
# 12         1000 mAh                -     ₹749
# 13                -                -  ₹22,849
# 14         5000 mAh                -   ₹7,679
# 15         5000 mAh                -   ₹7,669
# 16         5000 mAh            Li-Po  ₹10,996
# 17         6000 mAh       Li-Polymer   ₹7,938
# 18         6000 mAh       Li-Polymer   ₹8,000
# 19         1050 mAh           Li-ion   ₹1,399
# 20         5000 mAh       Li-Polymer  ₹14,935
# 21                -                -     ₹999
# 22                -                -     ₹999
# 23                -                -  ₹15,469
#
#                                                   URL
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/google-pixel-3a-clear...
# 2   https://www.flipkart.com/redmi-9-power-electri...
# 3   https://www.flipkart.com/redmi-9-power-mighty-...
# 4   https://www.flipkart.com/redmi-9-power-fiery-r...
# 5   https://www.flipkart.com/samsung-galaxy-m31-sp...
# 6   https://www.flipkart.com/itel-it2171/p/itmffyg...
# 7   https://www.flipkart.com/karbonn-kx3/p/itm60cf...
# 8   https://www.flipkart.com/karbonn-kx3/p/itmadce...
# 9   https://www.flipkart.com/lava-gem/p/itm77ce2fe...
# 10  https://www.flipkart.com/i-kall-k3310/p/itmevt...
# 11  https://www.flipkart.com/i-kall-k3310/p/itmevt...
# 12  https://www.flipkart.com/gfive-u707/p/itmfy49y...
# 13  https://www.flipkart.com/redmi-note-11t-5g-aqu...
# 14  https://www.flipkart.com/redmi-9a-midnight-bla...
# 15  https://www.flipkart.com/redmi-9a-nature-green...
# 16  https://www.flipkart.com/redmi-9-sky-blue-64-g...
# 17  https://www.flipkart.com/tecno-spark-7-magnet-...
# 18  https://www.flipkart.com/tecno-spark-7-spruce-...
# 19  https://www.flipkart.com/uismart-ui-06/p/itm04...
# 20  https://www.flipkart.com/tecno-camon-17-frost-...
# 21  https://www.flipkart.com/mtr-s600/p/itmfca730d...
# 22  https://www.flipkart.com/mtr-s600/p/itmfca730d...
# 23  https://www.flipkart.com/redmi-note-10-lite-gl...

# %% [markdown]
# . Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(2)

# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


search = driver.find_element_by_id("searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys("New Delhi")                                                     # entering values in search bar
button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# <ipython-input-31-0237baa7d97d>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
# <ipython-input-31-0237baa7d97d>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("searchboxinput")                       # locating search bar
# <ipython-input-31-0237baa7d97d>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
# URL Extracted:  https://www.google.co.in/maps/place/New+Delhi,+Delhi/@28.5272803,77.0688981,11z/data=!3m1!4b1!4m5!3m4!1s0x390cfd5b347eb62d:0x52c2b7494e204dce!8m2!3d28.6139391!4d77.2090212
# Latitude = 28.5272803, Longitude = 77.0688981

# %% [markdown]
# Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(2)

# opening trak.in
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# do click on funding deals
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# Empty lists
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

for i in range(48,51):
    # Date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
    
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
# <ipython-input-35-b92da2bdecc6>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
# <ipython-input-35-b92da2bdecc6>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
# <ipython-input-35-b92da2bdecc6>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
# <ipython-input-35-b92da2bdecc6>:32: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
# <ipython-input-35-b92da2bdecc6>:37: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
# <ipython-input-35-b92da2bdecc6>:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
# <ipython-input-35-b92da2bdecc6>:47: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
# <ipython-input-35-b92da2bdecc6>:52: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
# <ipython-input-35-b92da2bdecc6>:57: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
# <ipython-input-35-b92da2bdecc6>:62: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(2)
# Out:
# <ipython-input-9-7adcbc09f10d>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# getting the web page with given url
url = "https://www.digit.in/"
driver.get(url)

# now we will search for best gaming laptops
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
# Out:
# <ipython-input-10-21bfe424fb9b>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()

# %%
# creating empty lists to store all gaming laptop information
lap_name = []
op_stm = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_processor = []
prices = []

# fetching the laptop names
name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    lap_name.append(i.text)
    
# fetching information related to operating system
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        op_stm.append(i.text)
except NoSuchElementException:
    pass

# fetching information for display
try:
    disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in disp:
        display.append(i.text)
except NoSuchElementException:
    pass

# fetching information for processor
try:
    pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in pro:
        processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for memory
try:
    mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in mem:
        memory.append(i.text)
except NoSuchElementException:
    pass

# fetching information for weight
try:
    wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in wgt:
        weight.append(i.text)
except NoSuchElementException:
    pass

# fetching information for dimensions
try:
    dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dim:
        dimensions.append(i.text)
except NoSuchElementException:
    pass

# fetching information for graphic processor
try:
    g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in g_pro:
        graph_processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for i in price:
        prices.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# now creating a dataframe from all the collected details
data = list(zip(lap_name,op_stm,display,processor,memory,weight,dimensions,graph_processor,prices))
df = pd.DataFrame(data, columns = ["Laptop Name","Operating System","Display","Processor","Memory",
                                   "Weight(Kg)","Dimensions","Graphic-Processor","Price"])
df
# Out:
# <ipython-input-11-f5c0cfcd91f3>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
# <ipython-input-11-f5c0cfcd91f3>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:35: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:51: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:59: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:67: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
# <ipython-input-11-f5c0cfcd91f3>:75: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price = driver.find_elements_by_xpath("//td[@class='smprice']")
#                                      Laptop Name Operating System  \
# 0                    Acer NITRO 5 Ryzen 9 (2021)       Windows 10
# 1  MSI Stealth 15M 11th Gen Core i7-11375H (2021       Windows 10
# 2   ASUS ROG Strix Scar 15 Ryzen 9-5900HX (2021)       Windows 10
# 3                          Alienware Area 51M R2  Windows 10 Home
# 4                               Alienware m15 R3  Windows 10 Home
# 5                         ASUS ROG Strix Scar 15  Windows 10 Home
# 6                          Asus ROG Zephyrus G14  Windows 10 Home
# 7                               Lenovo Legion 5i   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           Acer Aspire 7 gaming  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 x 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 x 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 x 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 x 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 x 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 x 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 x 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 x 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#                    Memory Weight(Kg)               Dimensions  \
# 0   1 TB HDD/16 GBGB DDR4        2.4       363.4 x 255 x 23.9
# 1   1 TB SSD/16 GBGB DDR4        1.7      358.3 x 248 x 16.15
# 2   2 TB SSD/32 GBGB DDR4       2.30         354 x 259 x 22.6
# 3   1 TB SSD/16 GBGB DDR4        4.1   27.65 x 402.6 x 319.14
# 4   1 TB SSD/16 GBGB DDR4         NA                       NA
# 5   1 TB SSD/16 GBGB DDR4       2.30       35.4 x 25.9 x 2.26
# 6   1 TB SSD/16 GBGB DDR4       1.65        32.5 x 22.1 x 1.8
# 7   1 TB SSD/16 GBGB DDR4        2.3  363.06 x 259.61 x 23.57
# 8  512 GB SSD/4 GBGB DDR4        2.4  268.30 x 360.00 x 20.90
# 9  512 GB SSD/8 GBGB DDR4       2.15       2.29 x 36.3 x 25.4
#
#                Graphic-Processor        Price
# 0        NVIDIA GeForce RTX 3070  Rs  129,990
# 1        NVIDIA GeForce RTX 3060  Rs  134,990
# 2        NVIDIA GeForce RTX 3080  Rs  268,990
# 3        Intel® UHD Graphics 630  Rs  342,989
# 4                             NA  Rs  319,990
# 5      NVIDIA® GeForce RTX™ 3070  Rs  215,990
# 6        NVIDIA GeForce RTX 2060  Rs  164,990
# 7  NVIDIA® GeForce® GTX 1650 4GB   Rs  76,988
# 8  NVIDIA GeForce RTX 2070 Max-Q  Rs  185,000
# 9      NVIDIA® GeForce® GTX 1650   Rs  58,480

# %% [markdown]
# Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(2)
# Out:
# <ipython-input-12-7adcbc09f10d>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# obtaining the web page with given url
url = 'https://www.forbes.com/'
driver.get(url)
time.sleep(3)

# clicking on the hamburger option on the left side of the page
optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
optn.click()
time.sleep(1)

# now clicking on the 'Billionaires' option
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)

# finally clicking on the 'World Billionaire' option after the mouse hover
world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
# Out:
# <ipython-input-13-b10170ebd0fa>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
# <ipython-input-13-b10170ebd0fa>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
# <ipython-input-13-b10170ebd0fa>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")

# %%
# fetching the rank
rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass

# fetching the names of the billionaires
names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass

# fetching the total net worth
net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass

# fetching the age of the billionaires
Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')

 # fetching the citizenship of the billionaires
citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')
    
# fetching the source of incomes for the billionaires
source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
# fetching the industry in which the billionaires are prominent
industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
    
# now creating a dataframe from all the collected information
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
df
# Out:
# <ipython-input-14-22ab51fa8e39>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rnk = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-14-22ab51fa8e39>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//div[@class='personName']")
# <ipython-input-14-22ab51fa8e39>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
# <ipython-input-14-22ab51fa8e39>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age = driver.find_elements_by_xpath("//div[@class='age']")
# <ipython-input-14-22ab51fa8e39>:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-14-22ab51fa8e39>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src = driver.find_elements_by_xpath("//div[@class='source-column']")
# <ipython-input-14-22ab51fa8e39>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath("//div[@class='category']")
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(2)
# Out:
# <ipython-input-15-7adcbc09f10d>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Opening the youtube.com
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
#finding element for search bar
search_bar = driver.find_element_by_id('search')
search_bar.send_keys("BTS")  #entering Video name
time.sleep(1)
# Out:
# <ipython-input-17-f494a717e871>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id('search')
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-17-f494a717e871> in <module>
#       1 #finding element for search bar
#       2 search_bar = driver.find_element_by_id('search')
# ----> 3 search_bar.send_keys("BTS")  #entering Video name
#       4 time.sleep(1)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     538                 value = '\n'.join(remote_files)
#     539
# --> 540         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     541                       {'text': "".join(keys_to_typing(value)),
#     542                        'value': keys_to_typing(value)})
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01146903+2517251]
# 	Ordinal0 [0x010DF8E1+2095329]
# 	Ordinal0 [0x00FE2710+1058576]
# 	Ordinal0 [0x01008993+1214867]
# 	Ordinal0 [0x010080DF+1212639]
# 	Ordinal0 [0x010264D3+1336531]
# 	Ordinal0 [0x01003A36+1194550]
# 	Ordinal0 [0x010265BA+1336762]
# 	Ordinal0 [0x01035BBF+1399743]
# 	Ordinal0 [0x0102639B+1336219]
# 	Ordinal0 [0x010027A7+1189799]
# 	Ordinal0 [0x01003609+1193481]
# 	GetHandleVerifier [0x012D5904+1577972]
# 	GetHandleVerifier [0x01380B97+2279047]
# 	GetHandleVerifier [0x011D6D09+534521]
# 	GetHandleVerifier [0x011D5DB9+530601]
# 	Ordinal0 [0x010E4FF9+2117625]
# 	Ordinal0 [0x010E98A8+2136232]
# 	Ordinal0 [0x010E99E2+2136546]
# 	Ordinal0 [0x010F3541+2176321]
# 	BaseThreadInitThunk [0x753D6739+25]
# 	RtlGetFullPathName_UEx [0x773E8AFF+1215]
# 	RtlGetFullPathName_UEx [0x773E8ACD+1165]

# %%
#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)
# Out:
# <ipython-input-18-cac8bc6eb7b2>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_id("search-icon-legacy")

# %%
#clicking on first video
link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link_click.click()
# Out:
# <ipython-input-19-4e9d75198cf9>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-4e9d75198cf9> in <module>
#       1 #clicking on first video
# ----> 2 link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
#       3 link_click.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     518             stacklevel=2,
#     519         )
# --> 520         return self.find_element(by=By.XPATH, value=xpath)
#     521
#     522     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//yt-formatted-string[@class ='style-scope ytd-video-renderer']"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01146903+2517251]
# 	Ordinal0 [0x010DF8E1+2095329]
# 	Ordinal0 [0x00FE2848+1058888]
# 	Ordinal0 [0x0100D448+1233992]
# 	Ordinal0 [0x0100D63B+1234491]
# 	Ordinal0 [0x01037812+1406994]
# 	Ordinal0 [0x0102650A+1336586]
# 	Ordinal0 [0x01035BBF+1399743]
# 	Ordinal0 [0x0102639B+1336219]
# 	Ordinal0 [0x010027A7+1189799]
# 	Ordinal0 [0x01003609+1193481]
# 	GetHandleVerifier [0x012D5904+1577972]
# 	GetHandleVerifier [0x01380B97+2279047]
# 	GetHandleVerifier [0x011D6D09+534521]
# 	GetHandleVerifier [0x011D5DB9+530601]
# 	Ordinal0 [0x010E4FF9+2117625]
# 	Ordinal0 [0x010E98A8+2136232]
# 	Ordinal0 [0x010E99E2+2136546]
# 	Ordinal0 [0x010F3541+2176321]
# 	BaseThreadInitThunk [0x753D6739+25]
# 	RtlGetFullPathName_UEx [0x773E8AFF+1215]
# 	RtlGetFullPathName_UEx [0x773E8ACD+1165]

# %%
# we are going to scroll through the comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# creating empty lists to store the required information
comments = []
upvotes = []
times = []

# fetching all the comments
try:
    comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(5)

# fetching all the upvotes
try:
    up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    upvotes.append('-')
time.sleep(5)

# fetching all the time information indicating when the comment was made
try:
    timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    for i in timing:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(5)

# now we are creating a dataframe from the accumulated information
data = list(zip(comments,upvotes,times))
df = pd.DataFrame(data, columns = ["Comment","Upvotes","Published time"])
df
# Out:
# <ipython-input-20-6fe00dec486e>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
# <ipython-input-20-6fe00dec486e>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
# <ipython-input-20-6fe00dec486e>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
# Empty DataFrame
# Columns: [Comment, Upvotes, Published time]
# Index: []

# %% [markdown]
# Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description

# %%
# Activating the chrome brid=owser
driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe") 
#time.sleep(3)
# Out:
# <ipython-input-25-6d1dbfeb60b1>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# obtaining the web page from the given url
url = "https://www.hostelworld.com/"
driver.get(url)

# %%
#locating the location search bar
search_loc = driver.find_element_by_id('search-input-field')
# write Lonodn in search bar
search_loc.send_keys("London")
time.sleep(2)
# Out:
# <ipython-input-27-7ec16926eb01>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_loc = driver.find_element_by_id('search-input-field')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-27-7ec16926eb01> in <module>
#       1 #locating the location search bar
# ----> 2 search_loc = driver.find_element_by_id('search-input-field')
#       3 # write Lonodn in search bar
#       4 search_loc.send_keys("London")
#       5 time.sleep(2)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     470             stacklevel=2,
#     471         )
# --> 472         return self.find_element(by=By.ID, value=id_)
#     473
#     474     def find_elements_by_id(self, id_) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="search-input-field"]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01146903+2517251]
# 	Ordinal0 [0x010DF8E1+2095329]
# 	Ordinal0 [0x00FE2848+1058888]
# 	Ordinal0 [0x0100D448+1233992]
# 	Ordinal0 [0x0100D63B+1234491]
# 	Ordinal0 [0x01037812+1406994]
# 	Ordinal0 [0x0102650A+1336586]
# 	Ordinal0 [0x01035BBF+1399743]
# 	Ordinal0 [0x0102639B+1336219]
# 	Ordinal0 [0x010027A7+1189799]
# 	Ordinal0 [0x01003609+1193481]
# 	GetHandleVerifier [0x012D5904+1577972]
# 	GetHandleVerifier [0x01380B97+2279047]
# 	GetHandleVerifier [0x011D6D09+534521]
# 	GetHandleVerifier [0x011D5DB9+530601]
# 	Ordinal0 [0x010E4FF9+2117625]
# 	Ordinal0 [0x010E98A8+2136232]
# 	Ordinal0 [0x010E99E2+2136546]
# 	Ordinal0 [0x010F3541+2176321]
# 	BaseThreadInitThunk [0x753D6739+25]
# 	RtlGetFullPathName_UEx [0x773E8AFF+1215]
# 	RtlGetFullPathName_UEx [0x773E8ACD+1165]

# %%
#select london
london = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
london.click()
time.sleep(2)
# Out:
# <ipython-input-28-80fb84e68618>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   london = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-28-80fb84e68618> in <module>
#       1 #select london
# ----> 2 london = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
#       3 london.click()
#       4 time.sleep(2)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     518             stacklevel=2,
#     519         )
# --> 520         return self.find_element(by=By.XPATH, value=xpath)
#     521
#     522     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01146903+2517251]
# 	Ordinal0 [0x010DF8E1+2095329]
# 	Ordinal0 [0x00FE2848+1058888]
# 	Ordinal0 [0x0100D448+1233992]
# 	Ordinal0 [0x0100D63B+1234491]
# 	Ordinal0 [0x01037812+1406994]
# 	Ordinal0 [0x0102650A+1336586]
# 	Ordinal0 [0x01035BBF+1399743]
# 	Ordinal0 [0x0102639B+1336219]
# 	Ordinal0 [0x010027A7+1189799]
# 	Ordinal0 [0x01003609+1193481]
# 	GetHandleVerifier [0x012D5904+1577972]
# 	GetHandleVerifier [0x01380B97+2279047]
# 	GetHandleVerifier [0x011D6D09+534521]
# 	GetHandleVerifier [0x011D5DB9+530601]
# 	Ordinal0 [0x010E4FF9+2117625]
# 	Ordinal0 [0x010E98A8+2136232]
# 	Ordinal0 [0x010E99E2+2136546]
# 	Ordinal0 [0x010F3541+2176321]
# 	BaseThreadInitThunk [0x753D6739+25]
# 	RtlGetFullPathName_UEx [0x773E8AFF+1215]
# 	RtlGetFullPathName_UEx [0x773E8ACD+1165]

# %%
# do click on search button
search_btn = driver.find_element_by_id('search-button')
search_btn.click()
# Out:
# <ipython-input-29-fcf4923d7dc8>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_id('search-button')

# %%
# creating empty lists to collect the required information
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    
    # fetching hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        
    # fetching the distance from city centre    
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        
    # fetching the privates from price details
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
            
    # fetching the dorms from price information
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            
    # fetching all the facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
        
    # fetching the urls of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    
    # clicking on the show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    
    # fetching the ratings for the hostels
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
     # fetching the total reviews        
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        
    # fetching the overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
        
    # fetching the property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

# now creating a pandas dataframe to show all the collected data
data = list(zip(hostel_name,distance,rating,reviews,over_all,pvt_prices,dorms_price,facilities,description))       
df = pd.DataFrame(data, columns = ["Hostel name","Distance from city centre","ratings","Total reviews",
                                   "Overall review","Privates from price","Dorms from price","Facilities","Property Description"])
df
# Out:
# <ipython-input-30-1123cea14b35>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
# Empty DataFrame
# Columns: [Hostel name, Distance from city centre, ratings, Total reviews, Overall review, Privates from price, Dorms from price, Facilities, Property Description]
# Index: []
